# %% [markdown]
# <a href="https://colab.research.google.com/github/dinoboy22/Machine-learning-Math/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/content/drive/MyDrive/fake_bills.csv", sep=';')
df.head()
# Out:
#    is_genuine  diagonal  height_left  height_right  margin_low  margin_up  \
# 0        True    171.81       104.86        104.95        4.52       2.89
# 1        True    171.46       103.36        103.66        3.77       2.99
# 2        True    172.69       104.48        103.50        4.40       2.94
# 3        True    171.36       103.91        103.94        3.62       3.01
# 4        True    171.73       104.28        103.46        4.04       3.48
#
#    length
# 0  112.83
# 1  113.09
# 2  113.16
# 3  113.51
# 4  112.54

# %%
df.shape
# Out:
# (1500, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   is_genuine    1500 non-null   bool
#  1   diagonal      1500 non-null   float64
#  2   height_left   1500 non-null   float64
#  3   height_right  1500 non-null   float64
#  4   margin_low    1463 non-null   float64
#  5   margin_up     1500 non-null   float64
#  6   length        1500 non-null   float64
# dtypes: bool(1), float64(6)
# memory usage: 71.9 KB

# %%
df['is_genuine'] = df['is_genuine'].astype(int)

# %%
df
# Out:
#       is_genuine  diagonal  height_left  height_right  margin_low  margin_up  \
# 0              1    171.81       104.86        104.95        4.52       2.89
# 1              1    171.46       103.36        103.66        3.77       2.99
# 2              1    172.69       104.48        103.50        4.40       2.94
# 3              1    171.36       103.91        103.94        3.62       3.01
# 4              1    171.73       104.28        103.46        4.04       3.48
# ...          ...       ...          ...           ...         ...        ...
# 1495           0    171.75       104.38        104.17        4.42       3.09
# 1496           0    172.19       104.63        104.44        5.27       3.37
# 1497           0    171.80       104.01        104.12        5.51       3.36
# 1498           0    172.06       104.28        104.06        5.17       3.46
# 1499           0    171.47       104.15        103.82        4.63       3.37
#
#       length
# 0     112.83
# 1     113.09
# ...

# %%
import missingno as msno
msno.bar(df.iloc[:, :], color=(0.1, 0.6, 0.8))
# Out:
# <Axes: >

# %%
msno.matrix(df.iloc[:, :], color=(0.1, 0.6, 0.8))
# Out:
# <Axes: >

# %%
from sklearn.impute import KNNImputer
imputer = KNNImputer(n_neighbors=3)

# %%
cols = df.columns
df = imputer.fit_transform(df)

# %%
df = pd.DataFrame(df, columns=cols)
df.head()
# Out:
#    is_genuine  diagonal  height_left  height_right  margin_low  margin_up  \
# 0         1.0    171.81       104.86        104.95        4.52       2.89
# 1         1.0    171.46       103.36        103.66        3.77       2.99
# 2         1.0    172.69       104.48        103.50        4.40       2.94
# 3         1.0    171.36       103.91        103.94        3.62       3.01
# 4         1.0    171.73       104.28        103.46        4.04       3.48
#
#    length
# 0  112.83
# 1  113.09
# 2  113.16
# 3  113.51
# 4  112.54

# %%
msno.matrix(df.iloc[:, :], color=(0.1, 0.6, 0.8))
# Out:
# <Axes: >

# %%
msno.bar(df.iloc[:, :], color=(0.1, 0.6, 0.8))
# Out:
# <Axes: >

# %%
import seaborn as sns

corrcoef = np.corrcoef(df, rowvar=False)

# %%
corrcoef
# Out:
# array([[ 1.        ,  0.13275633, -0.37983292, -0.48509183, -0.78453164,
#         -0.60626226,  0.84928463],
#        [ 0.13275633,  1.        ,  0.01947232, -0.02449201, -0.11124579,
#         -0.05564888,  0.09758729],
#        [-0.37983292,  0.01947232,  1.        ,  0.24227881,  0.30671908,
#          0.24652224, -0.32086276],
#        [-0.48509183, -0.02449201,  0.24227881,  1.        ,  0.38972353,
#          0.30700464, -0.40175122],
#        [-0.78453164, -0.11124579,  0.30671908,  0.38972353,  1.        ,
#          0.42810231, -0.66467566],
#        [-0.60626226, -0.05564888,  0.24652224,  0.30700464,  0.42810231,
#          1.        , -0.52057513],
#        [ 0.84928463,  0.09758729, -0.32086276, -0.40175122, -0.66467566,
#         -0.52057513,  1.        ]])

# %%
corrcoef.shape
# Out:
# (7, 7)

# %%
sns.heatmap(corrcoef, annot=True, fmt='.2f', cbar=None, cmap='Reds')
# Out:
# <Axes: >

# %%
corr = df.corr()
sns.heatmap(corr, annot=True, fmt='.2f', cbar=None, cmap='Reds')
# Out:
# <Axes: >

# %%
sns.pairplot(df, diag_kind = 'kde', kind = 'hist')

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
X = df.iloc[:,1:]
y = df.iloc[:,0]
print(X.shape)
print(y.shape)
print(X.head())
print(y.head())
print(y.nunique())
# Out:
# (1500, 6)
# (1500,)
#    diagonal  height_left  height_right  margin_low  margin_up  length
# 0    171.81       104.86        104.95        4.52       2.89  112.83
# 1    171.46       103.36        103.66        3.77       2.99  113.09
# 2    172.69       104.48        103.50        4.40       2.94  113.16
# 3    171.36       103.91        103.94        3.62       3.01  113.51
# 4    171.73       104.28        103.46        4.04       3.48  112.54
# 0    1.0
# 1    1.0
# 2    1.0
# 3    1.0
# 4    1.0
# Name: is_genuine, dtype: float64
# 2

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=123, stratify=y)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import GridSearchCV

param_for_grid = {'n_neighbors': range(1, 20)}
knn = KNeighborsClassifier()
grid_search = GridSearchCV(knn, param_for_grid, cv=10)
grid_search.fit(X_train, y_train)
best_k = grid_search.best_params_['n_neighbors']
best_accuracy = grid_search.best_score_

print(best_k)
# Out:
# 6

# %%
best_knn = KNeighborsClassifier(n_neighbors = best_k)
best_knn.fit(X_train, y_train)
print('model score is: ' + str(round(best_knn.score(X_test, y_test)* 100, 0)) + '%')
# Out:
# model score is: 99.0%
